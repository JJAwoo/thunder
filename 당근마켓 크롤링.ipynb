# %%
# !pip install bs4

# %%
import requests
address = 'https://m.bunjang.co.kr/search/products?q=%EC%95%84%EC%9D%B4%ED%8F%B0'
res = requests.get(address)
res.encoding = None
from bs4 import BeautifulSoup as bs
soup = bs(res.text)

# %%
from bs4 import BeautifulSoup as bs
soup = bs(res.text)

# %%
# HTML 제목
print(soup.select_one)

# %%
[ s.text for s in soup.select('sc-iGPElx jrHpCR > div')]
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://m.bunjang.co.kr/search/products?q=%EC%95%84%EC%9D%B4%ED%8F%B0'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('div.sc-hdPSEv.kfFHxU > div > div:nth-child(1) > a ')
    print(title)
else : 
    print(response.status_code)
# Out:
# None

# %%
import requests
res = requests.get("#root > div > div > div:nth-child(4) ")
res.encoding=None
res.text

# %%
import requests
address = 'https://api.bunjang.co.kr/api/1/find_v2.json?q=%EC%95%84%EC%9D%B4%ED%8F%B011&order=score&page=0&request_id=2022519113337&stat_device=w&n=100&stat_category_required=1&req_ref=search&version=4' ,{}
res = requests.get(address)
res.encoding = None
from bs4 import BeautifulSoup as bs
soup = bs(res.text)


soup

# %%
for page_number in range(0,10): 

    url = "https://api.bunjang.co.kr/api/1/find_v2.json?q=%EC%95%84%EC%9D%B4%ED%8F%B011&order=score&page={0}&request_id=2022519113331&stat_device=w&n=100&stat_category_required=1&req_ref=search&version=4".format(page_number)
    res = requests.get(url)
    res.encoding=None
    data = res.json()
    for d in data['list']:
        print(d['name'], d['price'])
# Out:
# 파손폰매입 중고폰매입 고장폰 아이폰12 아이폰11 아이폰xs 아이폰x 555000
# [중고폰 매입] 깨진아이폰/고장폰/파손폰/아이폰xs/아이폰11/아이폰x 750000
# 아이폰11프로 64기가 초s급 490000
# 아이폰11pro 256gb 500000
# 정품 아이폰 11프로 가죽 케이스 20000
# 파손폰매입 중고폰매입 고장폰 아이폰파손 불량폰  부품폰 파손폰 11 12 777000
# 아이폰11 64기가 A급 화이트 54172 420000
# (A급)아이폰11프로 그레이 64 판매합니다 370000
# 아이폰 11 수냉 쿨링 폰케이스 10000
# 아이폰11프로  메탈 카메라 보호커버 3500
# 아이폰11프로 페이즐리 (반다나) 정품 35000
# *당일발송*아이폰11 최저가  판매 409000
# 아이폰11프로 케이스티파이 팬그램 정품 35000
# [순천중고폰][폰여기]아이폰11프로(64GB,골드)판매합니다 430000
# 아이폰11 젤리케이스 5000
# 아이폰11프로 케이스 10000
# 아이폰11 프로 화이트 B급 256GB 490000
# 아이폰11프로 256기가 골드  580000
# 방탄소년단 위불프 폰케이스 위블폰케 아이폰 11 터프 그립톡 판매 양도 9000
# 배터리91 A+급 아이폰11 128G 블랙 (572) 430000
# [대구]아이폰11/12프로/맥스 최고가로 현금으로 삽니다 1000000
# 중고폰매입 아이폰11,12,13,미니,프로,프로맥스 파손폰매입 888888
# *아이폰11 128GB 블랙 - 37610 290000
# 아이폰 11프로맥스 256g 물리 듀얼심 700000
# #한정판매# 아이폰11 128GB 화이트 [58383] 475000
# 아이폰11Pro 64GB 화이트 판매 중고 370000
# #당일발송# 아이폰11 64G/128G 등급별 중고폰 공기계! 375000
# (미개봉) 아이폰11 프로맥스 512GB 실버 955000
# 아이폰 11 디올 케이스 10000
# ...

# %%
    url = "https://api.bunjang.co.kr/api/1/find_v2.json?q=%EC%95%84%EC%9D%B4%ED%8F%B011&order=score&page=0&request_id=2022519113331&stat_device=w&n=100&stat_category_required=1&req_ref=search&version=4"
    res = requests.get(url)
    res.encoding=None
    data = res.json()
    data
# Out:
# {'result': 'success',
#  'no_result': False,
#  'no_result_type': None,
#  'no_result_message': None,
#  'ad_more_info': False,
#  'ad_products': [],
#  'list': [{'ad': True,
#    'bizseller': False,
#    'checkout': False,
#    'contact_hope': False,
#    'free_shipping': False,
#    'is_adult': False,
#    'is_super_up_shop': None,
#    'location': '인천광역시 부평구 부평1동',
#    'max_cpc': None,
#    'name': '파손폰매입 중고폰매입 고장폰 아이폰12 아이폰11 아이폰xs 아이폰x',
#    'num_comment': '0',
#    'num_faved': '206',
#    'only_neighborhood': False,
#    'outlink_url': '',
#    'pid': '182778662',
#    'price': '555000',
#    'product_image': 'https://media.bunjang.co.kr/product/182778662_1_1649157345_w{res}.jpg',
#    'pu_id': None,
#    'ref_campaign': '191544,580999,2495398,3313415,0:9h9dnxnT5/EwePQiufI5BuNBxfM96KiQvyzEFr8G4e8W8P2AUMpTkG17RAFJ3cXR:8:6',
#    'ref_code': '{"level1":"ad","level2":"sa","level3":"keyword","level4":"keyword-search"}',
#    'ref_medium': 'AD_N',
# ...
